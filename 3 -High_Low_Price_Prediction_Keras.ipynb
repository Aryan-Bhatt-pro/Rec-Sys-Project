# %% [markdown]
# # Long Short Term Memory(LSTM) based - Stock predicition - - # CPU based
#
#
# Aim -to predict the Closing_Price_Prediction using past 60 day stock price.

# %%
import math
import numpy as np
import pandas as pd
# import pandas_datareader as web
#from sklearn.tree import DecisionTreeRegressor
#from sklearn.linear_mode
#import LinearRegression
#from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras import Model
from keras.layers import Dense, LSTM, Dropout, Concatenate
from keras.optimizers import Adam
import matplotlib.pyplot as plt

#plt.style.use('fivethirtyeight')
#plt.style.use('fivethirtyeight')
plt.style.use('seaborn-v0_8-dark')

# %%
#choose plotting style

#plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
#plt.style.use('ggplot')
#plt.style.use('seaborn-whitegrid')
#plt.style.use('bmh')
#plt.style.use('seaborn')

# %%
df = []
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/AAPLStock_sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/AmazonStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/CSCOStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/IBMStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/JNJStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/JNPRStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/MSFTStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/ORCLStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/PfizerStock_Sentiment_6M.csv"))
df.append(pd.read_csv("Combining Stock and Twitter Data/MyDrive/TGTStock_Sentiment_6M.csv"))

# %%
df[0]
# Out:
#           date    open     low    high    volume     close  Name       Date  \
# 0    10/2/2017  154.26  152.72  154.45  18524860  153.8100  AAPL  10/2/2017
# 1    10/3/2017  154.01  153.91  155.09  16146388  154.4800  AAPL  10/3/2017
# 2    10/4/2017  153.63  152.46  153.86  19844177  153.4508  AAPL  10/4/2017
# 3    10/5/2017  154.18  154.05  155.44  21032800  155.3900  AAPL  10/5/2017
# 4    10/6/2017  154.97  154.56  155.49  16423749  155.3000  AAPL  10/6/2017
# ..         ...     ...     ...     ...       ...       ...   ...        ...
# 104   3/5/2018  175.21  174.52  177.74  28401366  176.8200  AAPL   3/5/2018
# 105   3/6/2018  177.91  176.13  178.25  23788506  176.6700  AAPL   3/6/2018
# 106   3/7/2018  174.94  174.27  175.85  31703462  175.0300  AAPL   3/7/2018
# 107   3/8/2018  175.48  175.07  177.12  23163767  176.9400  AAPL   3/8/2018
# 108   3/9/2018  177.96  177.39  180.00  31385134  179.9800  AAPL   3/9/2018
#
#        Positve   Negative    Neutral  Total  NeutralPos  NeutralNeg
# 0    23.960302   7.325142  68.714556   2116   41.836689    7.325142
# 1    37.554585   7.336245  55.109170   1145   41.825586    7.336245
# 2    41.138836  11.836212  47.024952   1563   41.138836   15.649430
# 3    39.038841   5.924951  55.036208   1519   43.236880    5.924951
# 4    49.426486   7.403545  43.169969    959   49.426486   15.071746
# ..         ...        ...        ...    ...         ...         ...
# 104  31.710914   5.653884  62.635202   2034   43.507946    5.653884
# 105  49.969715   5.511811  44.518474   1651   49.969715   11.831507
# 106  51.392962   6.671554  41.935484   1364   51.392962   15.574240
# 107  50.439239   6.954612  42.606149   1366   50.439239   15.186632
# 108  42.946429  10.357143  46.696429   1120   42.946429   14.498884
#
# [109 rows x 14 columns]

# %%
for i in df:
    i.drop(['date', 'Name', 'Date'], axis=1, inplace= True)

# %%
df[0]
# Out:
#        open     low    high    volume     close    Positve   Negative  \
# 0    154.26  152.72  154.45  18524860  153.8100  23.960302   7.325142
# 1    154.01  153.91  155.09  16146388  154.4800  37.554585   7.336245
# 2    153.63  152.46  153.86  19844177  153.4508  41.138836  11.836212
# 3    154.18  154.05  155.44  21032800  155.3900  39.038841   5.924951
# 4    154.97  154.56  155.49  16423749  155.3000  49.426486   7.403545
# ..      ...     ...     ...       ...       ...        ...        ...
# 104  175.21  174.52  177.74  28401366  176.8200  31.710914   5.653884
# 105  177.91  176.13  178.25  23788506  176.6700  49.969715   5.511811
# 106  174.94  174.27  175.85  31703462  175.0300  51.392962   6.671554
# 107  175.48  175.07  177.12  23163767  176.9400  50.439239   6.954612
# 108  177.96  177.39  180.00  31385134  179.9800  42.946429  10.357143
#
#        Neutral  Total  NeutralPos  NeutralNeg
# 0    68.714556   2116   41.836689    7.325142
# 1    55.109170   1145   41.825586    7.336245
# 2    47.024952   1563   41.138836   15.649430
# 3    55.036208   1519   43.236880    5.924951
# 4    43.169969    959   49.426486   15.071746
# ..         ...    ...         ...         ...
# 104  62.635202   2034   43.507946    5.653884
# 105  44.518474   1651   49.969715   11.831507
# 106  41.935484   1364   51.392962   15.574240
# 107  42.606149   1366   50.439239   15.186632
# 108  46.696429   1120   42.946429   14.498884
#
# [109 rows x 11 columns]

# %%
for i in df:
    i['diff']=i['high']-i['low']
for i in df:
    i['exp']=(i['open']+i['close'])/2

# %%
df[0]
# Out:
#        open     low    high    volume     close    Positve   Negative  \
# 0    154.26  152.72  154.45  18524860  153.8100  23.960302   7.325142
# 1    154.01  153.91  155.09  16146388  154.4800  37.554585   7.336245
# 2    153.63  152.46  153.86  19844177  153.4508  41.138836  11.836212
# 3    154.18  154.05  155.44  21032800  155.3900  39.038841   5.924951
# 4    154.97  154.56  155.49  16423749  155.3000  49.426486   7.403545
# ..      ...     ...     ...       ...       ...        ...        ...
# 104  175.21  174.52  177.74  28401366  176.8200  31.710914   5.653884
# 105  177.91  176.13  178.25  23788506  176.6700  49.969715   5.511811
# 106  174.94  174.27  175.85  31703462  175.0300  51.392962   6.671554
# 107  175.48  175.07  177.12  23163767  176.9400  50.439239   6.954612
# 108  177.96  177.39  180.00  31385134  179.9800  42.946429  10.357143
#
#        Neutral  Total  NeutralPos  NeutralNeg  diff       exp
# 0    68.714556   2116   41.836689    7.325142  1.73  154.0350
# 1    55.109170   1145   41.825586    7.336245  1.18  154.2450
# 2    47.024952   1563   41.138836   15.649430  1.40  153.5404
# 3    55.036208   1519   43.236880    5.924951  1.39  154.7850
# 4    43.169969    959   49.426486   15.071746  0.93  155.1350
# ..         ...    ...         ...         ...   ...       ...
# 104  62.635202   2034   43.507946    5.653884  3.22  176.0150
# 105  44.518474   1651   49.969715   11.831507  2.12  177.2900
# 106  41.935484   1364   51.392962   15.574240  1.58  174.9850
# 107  42.606149   1366   50.439239   15.186632  2.05  176.2100
# 108  46.696429   1120   42.946429   14.498884  2.61  178.9700
#
# [109 rows x 13 columns]

# %%
df[0].describe()
# Out:
#              open         low        high        volume       close  \
# count  109.000000  109.000000  109.000000  1.090000e+02  109.000000
# mean   168.903349  167.669458  170.316909  3.050903e+07  169.088650
# std      7.487566    7.587294    7.385025  1.299311e+07    7.466276
# min    153.630000  150.240000  153.860000  1.402652e+07  153.450800
# 25%    163.085000  161.650000  166.800000  2.165446e+07  164.340000
# 50%    171.180000  170.060000  172.620000  2.822436e+07  171.340000
# 75%    174.505000  173.340000  175.390000  3.688643e+07  174.670000
# max    179.370000  178.250000  180.615000  8.543608e+07  179.980000
#
#           Positve    Negative     Neutral        Total  NeutralPos  \
# count  109.000000  109.000000  109.000000   109.000000  109.000000
# mean    42.489354   10.002289   47.489824  1537.550459   43.832380
# std      5.672509    3.003885    6.400152   566.110094    4.051059
# min     23.960302    5.511811   32.961783   161.000000   35.366972
# 25%     38.561151    7.699531   43.191362  1192.000000   41.275942
# 50%     43.013522    9.711075   46.707317  1427.000000   43.236880
# 75%     45.667244   11.720554   51.245886  1751.000000   45.667244
# max     55.161290   21.330275   68.714556  3909.000000   55.161290
#
#        NeutralNeg        diff         exp
# count  109.000000  109.000000  109.000000
# mean    14.693661    2.647451  168.995999
# std      6.200383    1.635597    7.415254
# min      5.626851    0.854100  153.540400
# 25%      9.465021    1.570000  163.185000
# 50%     14.304836    2.180000  171.210000
# 75%     19.023173    3.140000  174.570000
# max     33.068793    9.720000  179.315000

# %%
#Scale the data

# scaler = [MinMaxScaler(feature_range=(0,1)) for _ in range(len(df))]
# for i in range(len(df)):
#     df[i][['open', 'low', 'high', 'volume', 'close', 'Total', 'diff']] = scaler[i].fit_transform(
#         df[i][['open', 'low', 'high', 'volume', 'close', 'Total', 'diff']])
# for i in df:
#     i[['Positve', 'Negative', 'Neutral', 'NeutralPos', 'NeutralNeg']] = i[[
#         'Positve', 'Negative', 'Neutral', 'NeutralPos', 'NeutralNeg']]/100

scaler = [MinMaxScaler(feature_range=(0, 1)) for _ in range(len(df))]
for i in range(len(df)):
    df[i][df[i].columns] = scaler[i].fit_transform(df[i][df[i].columns])

df[0]
# Out:
#          open       low      high    volume     close   Positve  Negative  \
# 0    0.024476  0.088540  0.022052  0.062994  0.013540  0.000000  0.114634
# 1    0.014763  0.131025  0.045973  0.029686  0.038795  0.435700  0.115336
# 2    0.000000  0.079257  0.000000  0.081469  0.000000  0.550577  0.399811
# 3    0.021368  0.136023  0.059054  0.098114  0.073097  0.483271  0.026118
# 4    0.052059  0.154231  0.060923  0.033570  0.069704  0.816198  0.119590
# ..        ...       ...       ...       ...       ...       ...       ...
# 104  0.838384  0.866833  0.892543  0.201301  0.880886  0.248409  0.008981
# 105  0.943279  0.924313  0.911605  0.136704  0.875232  0.833609  0.000000
# 106  0.827894  0.857908  0.821902  0.247543  0.813413  0.879224  0.073316
# 107  0.848873  0.886469  0.869370  0.127956  0.885409  0.848657  0.091210
# 108  0.945221  0.969297  0.977014  0.243085  1.000000  0.608510  0.306309
#
#       Neutral     Total  NeutralPos  NeutralNeg      diff       exp
# 0    1.000000  0.521612    0.326847    0.061887  0.098794  0.019189
# 1    0.619459  0.262540    0.326286    0.062291  0.036759  0.027337
# 2    0.393345  0.374066    0.291592    0.365228  0.061573  0.000000
# 3    0.617419  0.362327    0.397584    0.010863  0.060445  0.048288
# 4    0.285522  0.212914    0.710280    0.344177  0.008561  0.061867
# ..        ...       ...         ...         ...       ...       ...
# 104  0.829961  0.499733    0.411278    0.000985  0.266854  0.871967
# 105  0.323239  0.397545    0.737724    0.226101  0.142783  0.921434
# 106  0.250993  0.320971    0.809626    0.362489  0.081876  0.832005
# 107  0.269752  0.321505    0.761444    0.348364  0.134888  0.879533
# 108  0.384156  0.255870    0.382911    0.323302  0.198051  0.986615
#
# [109 rows x 13 columns]

# %%
df[0].describe()
# Out:
#              open         low        high      volume       close     Positve  \
# count  109.000000  109.000000  109.000000  109.000000  109.000000  109.000000
# mean     0.593370    0.622258    0.615097    0.230817    0.589458    0.593861
# std      0.290892    0.270878    0.276024    0.181952    0.281436    0.181805
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.367327    0.407355    0.483648    0.106820    0.410461    0.467961
# 50%      0.681818    0.707604    0.701177    0.198823    0.674321    0.610661
# 75%      0.810995    0.824705    0.804709    0.320124    0.799843    0.695713
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          Negative     Neutral       Total  NeutralPos  NeutralNeg        diff  \
# count  109.000000  109.000000  109.000000  109.000000  109.000000  109.000000
# mean     0.283876    0.406347    0.367276    0.427669    0.330400    0.202275
# std      0.189897    0.179011    0.151043    0.204658    0.225945    0.184482
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.138302    0.286120    0.275080    0.298518    0.139865    0.080748
# 50%      0.265466    0.384461    0.337780    0.397584    0.316231    0.149551
# 75%      0.392500    0.511404    0.424226    0.520365    0.488170    0.257831
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               exp
# count  109.000000
# mean     0.599645
# std      0.287696
# min      0.000000
# 25%      0.374190
# 50%      0.685543
# 75%      0.815904
# max      1.000000

# %%
dataset = []
for i in df:
    dataset.append(i.values)
dataset
# Out:
# [array([[0.02447552, 0.08853981, 0.02205195, ..., 0.06188668, 0.09879426,
#          0.01918943],
#         [0.01476301, 0.13102463, 0.04597272, ..., 0.06229128, 0.03675882,
#          0.02733699],
#         [0.        , 0.07925741, 0.        , ..., 0.36522848, 0.06157299,
#          0.        ],
#         ...,
#         [0.82789433, 0.85790789, 0.82190245, ..., 0.36248852, 0.0818755 ,
#          0.83200515],
#         [0.84887335, 0.88646912, 0.86937021, ..., 0.34836387, 0.1348876 ,
#          0.87953256],
#         [0.94522145, 0.96929668, 0.97701364, ..., 0.32330193, 0.19805096,
#          0.98661473]]),
#  array([[0.01606788, 0.0028751 , 0.00587566, ..., 0.28891541, 0.07141165,
#          0.00659176],
#         [0.00622035, 0.        , 0.        , ..., 0.49960721, 0.05734118,
#          0.        ],
#         [0.        , 0.00604557, 0.00666396, ..., 0.42908698, 0.06051003,
#          0.0037155 ],
#         ...,
#         [0.93930641, 0.93992213, 0.94629825, ..., 0.43210055, 0.13331824,
#          0.94225489],
#         [0.97784306, 0.97727982, 0.96089395, ..., 0.35225686, 0.02950053,
#          0.96697602],
#         [1.        , 1.        , 1.        , ..., 0.52897854, 0.10668477,
#          1.        ]]),
#  array([[0.02880658, 0.03014643, 0.02493966, ..., 0.360432  , 0.02872531,
#          0.03510238],
#         [0.03786008, 0.03789836, 0.03539823, ..., 0.21076173, 0.04308797,
#          0.04387798],
#         [0.02222222, 0.01033592, 0.00804505, ..., 0.21002977, 0.03590664,
#          0.01880485],
#         ...,
#         [0.88641975, 0.91559001, 0.87932422, ..., 0.29982311, 0.1508079 ,
#          0.90722942],
#         [0.90452675, 0.92721792, 0.88093323, ..., 0.13283302, 0.10951526,
#          0.9222733 ],
#         [0.93497942, 0.98535745, 0.97184232, ..., 0.37557919, 0.27289048,
#          0.98077727]]),
#  array([[0.        , 0.03428824, 0.00061779, ..., 0.123745  , 0.14115433,
#          0.        ],
#         [0.05436105, 0.08185817, 0.01441104, ..., 0.12709048, 0.04139272,
#          0.0309913 ],
#         [0.06693712, 0.0721758 , 0.00700165, ..., 0.45790722, 0.0476788 ,
#          0.03120357],
#         ...,
#         [0.39148073, 0.43505441, 0.49341021, ..., 0.29029185, 0.44792974,
#          0.45234557],
#         [0.55375254, 0.44936749, 0.52388797, ..., 0.3083336 , 0.49811794,
#          0.49246444],
#         [0.49168357, 0.54324444, 0.5244028 , ..., 0.09721557, 0.21988708,
#          0.5257907 ]]),
#  array([[0.1552795 , 0.32030932, 0.11556481, ..., 0.0767278 , 0.0468145 ,
#          0.14332826],
#         [0.22646918, 0.37484737, 0.17126497, ..., 0.07116241, 0.02780711,
#          0.20345003],
#         [0.26230291, 0.4049654 , 0.21186882, ..., 0.11408789, 0.03062302,
#          0.24251649],
#         ...,
#         [0.02723364, 0.20838421, 0.01145237, ..., 0.13860527, 0.09961281,
#          0.02004059],
#         [0.11562351, 0.29222629, 0.16605934, ..., 0.11585172, 0.16367476,
#          0.14358194],
#         [0.22073579, 0.38176638, 0.18688183, ..., 0.11585172, 0.03695882,
#          0.21106038]]),
#  array([[0.77245509, 0.79369919, 0.70398482, ..., 0.14439192, 0.27245336,
#          0.81118143],
#         [0.85828343, 0.8648374 , 0.73434535, ..., 0.31284916, 0.15065068,
#          0.87341772],
#         [0.89221557, 0.90853659, 0.77514231, ..., 0.11376333, 0.15065068,
#          0.907173  ],
#         ...,
#         [0.34730539, 0.3699187 , 0.25237192, ..., 0.31241942, 0.08333868,
#          0.32172996],
#         [0.36726547, 0.38414634, 0.26185958, ..., 0.12513966, 0.07051734,
#          0.35021097],
#         [0.41516966, 0.43902439, 0.33396584, ..., 0.31284916, 0.14103468,
#          0.41666667]]),
#  array([[0.03265869, 0.02747769, 0.01329056, ..., 0.24063665, 0.06372133,
#          0.01460362],
#         [0.03081877, 0.02278065, 0.00733272, ..., 0.16365588, 0.05862362,
#          0.00556328],
#         [0.        , 0.        , 0.        , ..., 0.13901062, 0.11384877,
#          0.        ],
#         ...,
#         [0.88132475, 0.87928605, 0.88087076, ..., 0.45809825, 0.19891249,
#          0.88850255],
#         [0.9323827 , 0.94199155, 0.9340055 , ..., 0.2342669 , 0.16907392,
#          0.92744553],
#         [0.97930083, 1.        , 1.        , ..., 0.24883865, 0.20390824,
#          1.        ]]),
#  array([[0.27389706, 0.42197452, 0.28571429, ..., 0.27758822, 0.07723891,
#          0.29856115],
#         [0.31617647, 0.41719745, 0.27857143, ..., 0.26599522, 0.07317371,
#          0.30935252],
#         [0.32352941, 0.4522293 , 0.31964286, ..., 0.63816151, 0.07723891,
#          0.33183453],
#         ...,
#         [0.70404412, 0.81369427, 0.7875    , ..., 0.37235924, 0.21952112,
#          0.77158273],
#         [0.86580882, 0.88296178, 0.85      , ..., 0.11947608, 0.18496687,
#          0.88758993],
#         [0.94117647, 1.        , 1.        , ..., 0.13960173, 0.22765153,
#          1.        ]]),
#  array([[0.31198347, 0.41113106, 0.334     , ..., 0.14787765, 0.17063492,
#          0.35056877],
#         [0.38429752, 0.45780969, 0.354     , ..., 0.35283131, 0.10714286,
#          0.39400207],
#         [0.41735537, 0.48473968, 0.362     , ..., 0.07153524, 0.06349206,
#          0.39193382],
#         ...,
#         [0.29752066, 0.42190305, 0.33      , ..., 0.21980656, 0.13888889,
#          0.32885212],
#         [0.37809917, 0.49012567, 0.414     , ..., 0.11950998, 0.1547619 ,
#          0.42812823],
#         [0.53512397, 0.50628366, 0.574     , ..., 0.11950998, 0.43650794,
#          0.57911065]]),
#  array([[0.17781471, 0.15378151, 0.16082121, ..., 0.122179  , 0.21318681,
#          0.17137396],
#         [0.18861654, 0.18487395, 0.16766467, ..., 0.12747058, 0.08571429,
#          0.17031217],
#         [0.1732447 , 0.18823529, 0.15440547, ..., 0.10822178, 0.        ,
#          0.16415375],
#         ...,
#         [0.6875779 , 0.69495798, 0.71941831, ..., 0.34766638, 0.25274725,
#          0.69823742],
#         [0.70294973, 0.63487395, 0.69546621, ..., 0.55962542, 0.44395604,
#          0.67041835],
#         [0.65932696, 0.64243697, 0.66295979, ..., 0.40748652, 0.23736264,
#          0.66383521]])]

# %%
#Create training dataset
#Create scaled training dataset

# train_data = [i[0:training_data_len[0],:] for i in dataset]

#Split the data into x_train and y_train data set

x=[]
y=[]
x_company = [[] for _ in range(len(dataset))]
y_company = [[] for _ in range(len(dataset))]

flag=True
input_seq_len=30
test_index=[]
c=0
for i in dataset:
    for j in range(input_seq_len, len(i)):
        x.append(i[j-input_seq_len:j])
        y.append([i[j][11], i[j][12]])
        x_company[c].append(i[j-input_seq_len:j])
        y_company[c].append([i[j][11], i[j][12]])
        if flag:
            # print(x_train)
            print(y)
            print()
            flag=False
    x_company[c] = np.array(x_company[c])
    y_company[c] = np.array(y_company[c])
    c+=1

len(x_company[0])
# Out:
# [[0.16308552995183712, 0.7235650601755221]]
# 79

# %%
x_company[0]
# Out:
# array([[[0.02447552, 0.08853981, 0.02205195, ..., 0.06188668,
#          0.09879426, 0.01918943],
#         [0.01476301, 0.13102463, 0.04597272, ..., 0.06229128,
#          0.03675882, 0.02733699],
#         [0.        , 0.07925741, 0.        , ..., 0.36522848,
#          0.06157299, 0.        ],
#         ...,
#         [0.83449883, 0.81756516, 0.83105962, ..., 0.08631241,
#          0.2369641 , 0.85179207],
#         [0.83449883, 0.85790789, 0.80433564, ..., 0.48652831,
#          0.0288634 , 0.82831935],
#         [0.77195027, 0.82684755, 0.77144459, ..., 0.32628917,
#          0.02773548, 0.78350779]],
#
#        [[0.01476301, 0.13102463, 0.04597272, ..., 0.06229128,
#          0.03675882, 0.02733699],
#         [0.        , 0.07925741, 0.        , ..., 0.36522848,
#          0.06157299, 0.        ],
#         [0.02136752, 0.13602285, 0.05905438, ..., 0.01086292,
#          0.06044508, 0.04828785],
#         ...,
#         [0.83449883, 0.85790789, 0.80433564, ..., 0.48652831,
#          0.0288634 , 0.82831935],
#         [0.77195027, 0.82684755, 0.77144459, ..., 0.32628917,
#          0.02773548, 0.78350779],
#         [0.75407925, 0.74759015, 0.73332087, ..., 0.09549513,
#          0.16308553, 0.72356506]],
#
#        [[0.        , 0.07925741, 0.        , ..., 0.36522848,
#          0.06157299, 0.        ],
#         [0.02136752, 0.13602285, 0.05905438, ..., 0.01086292,
#          0.06044508, 0.04828785],
#         [0.05205905, 0.15423063, 0.06092319, ..., 0.34417736,
#          0.00856089, 0.06186711],
#         ...,
#         [0.77195027, 0.82684755, 0.77144459, ..., 0.32628917,
#          0.02773548, 0.78350779],
#         [0.75407925, 0.74759015, 0.73332087, ..., 0.09549513,
#          0.16308553, 0.72356506],
#         [0.63480963, 0.64762585, 0.6152009 , ..., 0.52042233,
#          0.12244668, 0.62016869]],
#
#        ...,
#
#        [[0.91958042, 0.9489468 , 0.95608298, ..., 0.44522786,
#          0.19917888, 0.91677853],
#         [0.91763792, 0.81970725, 0.87609793, ..., 0.58271657,
#          0.3661106 , 0.86110357],
#         [0.81099456, 0.72438415, 0.78826388, ..., 0.65963312,
#          0.40220395, 0.74752275],
#         ...,
#         [0.74475524, 0.7929311 , 0.83872173, ..., 0.30247544,
#          0.33791268, 0.81338217],
#         [0.83838384, 0.86683327, 0.89254345, ..., 0.0009851 ,
#          0.2668539 , 0.87196698],
#         [0.94327894, 0.92431275, 0.91160531, ..., 0.2261012 ,
#          0.14278302, 0.92143428]],
#
#        [[0.91763792, 0.81970725, 0.87609793, ..., 0.58271657,
#          0.3661106 , 0.86110357],
#         [0.81099456, 0.72438415, 0.78826388, ..., 0.65963312,
#          0.40220395, 0.74752275],
#         [0.71367521, 0.70760443, 0.67800411, ..., 0.88157791,
#          0.12248052, 0.70668798],
#         ...,
#         [0.83838384, 0.86683327, 0.89254345, ..., 0.0009851 ,
#          0.2668539 , 0.87196698],
#         [0.94327894, 0.92431275, 0.91160531, ..., 0.2261012 ,
#          0.14278302, 0.92143428],
#         [0.82789433, 0.85790789, 0.82190245, ..., 0.36248852,
#          0.0818755 , 0.83200515]],
#
#        [[0.81099456, 0.72438415, 0.78826388, ..., 0.65963312,
#          0.40220395, 0.74752275],
#         [0.71367521, 0.70760443, 0.67800411, ..., 0.88157791,
#          0.12248052, 0.70668798],
#         [0.64219114, 0.60085684, 0.60923192, ..., 0.64097623,
#          0.25219098, 0.60212768],
#         ...,
#         [0.94327894, 0.92431275, 0.91160531, ..., 0.2261012 ,
#          0.14278302, 0.92143428],
#         [0.82789433, 0.85790789, 0.82190245, ..., 0.36248852,
#          0.0818755 , 0.83200515],
#         [0.84887335, 0.88646912, 0.86937021, ..., 0.34836387,
#          0.1348876 , 0.87953256]]])

# %%
#convert the x_train and y_train to numpy arrays
x, y = np.array(x), np.array(y)

# %%
x
# Out:
# array([[[0.02447552, 0.08853981, 0.02205195, ..., 0.06188668,
#          0.09879426, 0.01918943],
#         [0.01476301, 0.13102463, 0.04597272, ..., 0.06229128,
#          0.03675882, 0.02733699],
#         [0.        , 0.07925741, 0.        , ..., 0.36522848,
#          0.06157299, 0.        ],
#         ...,
#         [0.83449883, 0.81756516, 0.83105962, ..., 0.08631241,
#          0.2369641 , 0.85179207],
#         [0.83449883, 0.85790789, 0.80433564, ..., 0.48652831,
#          0.0288634 , 0.82831935],
#         [0.77195027, 0.82684755, 0.77144459, ..., 0.32628917,
#          0.02773548, 0.78350779]],
#
#        [[0.01476301, 0.13102463, 0.04597272, ..., 0.06229128,
#          0.03675882, 0.02733699],
#         [0.        , 0.07925741, 0.        , ..., 0.36522848,
#          0.06157299, 0.        ],
#         [0.02136752, 0.13602285, 0.05905438, ..., 0.01086292,
#          0.06044508, 0.04828785],
#         ...,
#         [0.83449883, 0.85790789, 0.80433564, ..., 0.48652831,
#          0.0288634 , 0.82831935],
#         [0.77195027, 0.82684755, 0.77144459, ..., 0.32628917,
#          0.02773548, 0.78350779],
#         [0.75407925, 0.74759015, 0.73332087, ..., 0.09549513,
#          0.16308553, 0.72356506]],
#
#        [[0.        , 0.07925741, 0.        , ..., 0.36522848,
#          0.06157299, 0.        ],
#         [0.02136752, 0.13602285, 0.05905438, ..., 0.01086292,
#          0.06044508, 0.04828785],
#         [0.05205905, 0.15423063, 0.06092319, ..., 0.34417736,
#          0.00856089, 0.06186711],
#         ...,
#         [0.77195027, 0.82684755, 0.77144459, ..., 0.32628917,
#          0.02773548, 0.78350779],
#         [0.75407925, 0.74759015, 0.73332087, ..., 0.09549513,
#          0.16308553, 0.72356506],
#         [0.63480963, 0.64762585, 0.6152009 , ..., 0.52042233,
#          0.12244668, 0.62016869]],
#
#        ...,
#
#        [[1.        , 1.        , 1.        , ..., 0.20970416,
#          0.0989011 , 1.        ],
#         [0.98795181, 0.93823529, 0.98246364, ..., 0.33449835,
#          0.33186813, 0.96772138],
#         [0.95720814, 0.91260504, 0.95124038, ..., 0.53381561,
#          0.30549451, 0.9394776 ],
#         ...,
#         [0.79434981, 0.8092437 , 0.86227545, ..., 0.27613646,
#          0.38901099, 0.83181142],
#         [0.84171167, 0.83644958, 0.87382378, ..., 0.37337504,
#          0.30604396, 0.85580803],
#         [0.82010802, 0.66806723, 0.82634731, ..., 0.5026178 ,
#          0.94285714, 0.77362497]],
#
#        [[0.98795181, 0.93823529, 0.98246364, ..., 0.33449835,
#          0.33186813, 0.96772138],
#         [0.95720814, 0.91260504, 0.95124038, ..., 0.53381561,
#          0.30549451, 0.9394776 ],
#         [0.91857084, 0.91491597, 0.92814371, ..., 0.16626943,
#          0.17472527, 0.93353154],
#         ...,
#         [0.84171167, 0.83644958, 0.87382378, ..., 0.37337504,
#          0.30604396, 0.85580803],
#         [0.82010802, 0.66806723, 0.82634731, ..., 0.5026178 ,
#          0.94285714, 0.77362497],
#         [0.6875779 , 0.69495798, 0.71941831, ..., 0.34766638,
#          0.25274725, 0.69823742]],
#
#        [[0.95720814, 0.91260504, 0.95124038, ..., 0.53381561,
#          0.30549451, 0.9394776 ],
#         [0.91857084, 0.91491597, 0.92814371, ..., 0.16626943,
#          0.17472527, 0.93353154],
#         [0.92064811, 0.93865546, 0.9332763 , ..., 0.14052342,
#          0.07692308, 0.93140794],
#         ...,
#         [0.82010802, 0.66806723, 0.82634731, ..., 0.5026178 ,
#          0.94285714, 0.77362497],
#         [0.6875779 , 0.69495798, 0.71941831, ..., 0.34766638,
#          0.25274725, 0.69823742],
#         [0.70294973, 0.63487395, 0.69546621, ..., 0.55962542,
#          0.44395604, 0.67041835]]])

# %%
x.shape
# Out:
# (790, 30, 13)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %%
X_train.shape
# Out:
# (711, 30, 13)

# %%
Y_train.shape
# Out:
# (711, 2)

# %% [markdown]
# ## Model training

# %%
class MyModel(Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.lstm1 = LSTM(units=50, return_sequences=True,
                           input_shape=X_train.shape[1:])
        self.lstm2 = LSTM(units=60, return_sequences=True)
        self.lstm3 = LSTM(units=80, return_sequences=True)
        self.lstm4 = LSTM(units=120)
        self.dense1_1 = Dense(30)
        self.dense1_2 = Dense(30)
        self.concat = Concatenate(axis=-1)
        self.dense2 = Dense(2)

    def call(self, inputs):
        enc = self.lstm1(inputs)
        enc = self.lstm2(enc)
        enc = self.lstm3(enc)
        enc = self.lstm4(enc)
        high = self.dense1_1(enc)
        diff = self.dense1_2(enc)
        out = self.concat([high, diff])
        return self.dense2(out)

# %%
# #Build LSTM model
# model=Sequential()
# # #Add first layer to model
# # model.add(LSTM(50, return_sequences=True, input_shape=X_train.shape[1:]))
# # #Add second layer to model
# # model.add(LSTM(50, return_sequences=False))
# # #Add Dense Layer to model with 25 neurons
# # model.add(Dense(25))
# # #Add Dense Layer to model with 2 neuron
# # model.add(Dense(Y_train.shape[1]))

# model.add(LSTM(units=50, return_sequences=True,
#           input_shape=X_train.shape[1:]))
# # model.add(Dropout(0.2))

# model.add(LSTM(units=60, return_sequences=True))
# # model.add(Dropout(0.3))

# model.add(LSTM(units=80, return_sequences=True))
# # model.add(Dropout(0.4))

# model.add(LSTM(units=120))
# # model.add(Dropout(0.5))

# model.add(Dense(30))

# model.add(Dense(units=Y_train.shape[1], activation="relu"))

model = MyModel()

# %%
from tensorflow.keras.losses import MeanSquaredLogarithmicError, MeanSquaredError
from tensorflow.keras.saving import register_keras_serializable

@register_keras_serializable(package="MyLoss")
def MyLoss(y_true, y_pred):
    msle = MeanSquaredLogarithmicError()(y_true[:,0], y_pred[:,0])
    mse = MeanSquaredError()(y_true[:,1],y_pred[:,1])
    return  msle + mse
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       1 from tensorflow.keras.losses import MeanSquaredLogarithmicError, MeanSquaredError
#       2 from tensorflow.keras.saving import register_keras_serializable
# ----> 4 @register_keras_serializable(package="MyLoss")
#       5 def MyLoss(y_true, y_pred):
#       6     msle = MeanSquaredLogarithmicError()(y_true[:,0], y_pred[:,0])
#       7     mse = MeanSquaredError()(y_true[:,1],y_pred[:,1])
#
# File ~/anaconda3/envs/recsys/lib/python3.11/site-packages/keras/saving/object_registration.py:154, in register_keras_serializable.<locals>.decorator(arg)
#     148     raise ValueError(
#     149         "Cannot register a class that does not have a "
#     150         "get_config() method."
#     151     )
#     153 if registered_name in _GLOBAL_CUSTOM_OBJECTS:
# --> 154     raise ValueError(
#     155         f"{registered_name} has already been registered to "
#     156         f"{_GLOBAL_CUSTOM_OBJECTS[registered_name]}"
#     157     )
#     159 if arg in _GLOBAL_CUSTOM_NAMES:
#     160     raise ValueError(
#     161         f"{arg} has already been registered to "
#     162         f"{_GLOBAL_CUSTOM_NAMES[arg]}"
#     163     )
#
# ValueError: MyLoss>MyLoss has already been registered to <function MyLoss at 0x7f52bcf3d300>

# %%
#Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=MyLoss, metrics=['mse', 'msle'])

# %%
#Train the model
model.fit(X_train, Y_train, batch_size=32, epochs=100, validation_data=(X_test, Y_test))

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss=MyLoss, metrics=['mse', 'msle'])

# %%
# Train the model
model.fit(X_train, Y_train, batch_size=32, epochs=50,
          validation_data=(X_test, Y_test))

# %%
model.save('model', save_format='tf')

# %% [markdown]
# ## Checking model Load

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('model')
# Out:
# 2024-05-02 23:59:05.815257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:05.815351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:05.815410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:05.865473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:05.865568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:05.865644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:05.980560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:05.982152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:05.982574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:05.996916: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:05.997002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:05.997060: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:06.060809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:06.060914: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:06.060976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:06.107775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:06.107968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:06.108038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:06.134587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:06.134688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:06.134747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:06.309440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:06.309568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:06.309631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:06.475933: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:06.476036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:06.476097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:06.546188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:06.546320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:06.546382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.296011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.296109: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.296166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.352652: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.352755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.352814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.434501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.434642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.434733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.462043: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.462185: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.462275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.482615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.482709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.482795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.631177: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.631271: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.631329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.676785: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.676886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.676951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.726995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.727082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.727139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.749640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.750920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.751925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.879887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.880006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.880064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:07.920386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:07.920524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:07.920616: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.105621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.105714: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.105777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.158681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.158775: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.158846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.233711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.233841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.233908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.365147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.365280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.365371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.522994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.523099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.523158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.648902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.649004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.649064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.675875: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.675970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.676028: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.701465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.701553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.701610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.732101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.732215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.732275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.773045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.773135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.773192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:08.948640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:08.948769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:08.948828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.002072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.003020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.003684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.184301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.184421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.184483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.210925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.211719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.211783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.476858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.477033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.477136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.546566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.546655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.546713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.586887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.586988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.587049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.662639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.662743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.662804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.918040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.918133: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.918192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.944941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.945035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.945094: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:09.969762: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:09.969889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:09.969953: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:10.056138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:10.056228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:10.056287: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]
# 2024-05-02 23:59:10.164783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_2_grad_concat_split_2_split_dim' with dtype int32
# 	 [[{{node gradients_split_2_grad_concat_split_2_split_dim}}]]
# 2024-05-02 23:59:10.164872: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_grad_concat_split_split_dim' with dtype int32
# 	 [[{{node gradients_split_grad_concat_split_split_dim}}]]
# 2024-05-02 23:59:10.164939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients_split_1_grad_concat_split_1_split_dim' with dtype int32
# 	 [[{{node gradients_split_1_grad_concat_split_1_split_dim}}]]

# %% [markdown]
# ## Testing and Validating model

# %%
df[0].columns

# %%
#Get the models predicted price values

predictions = [pd.DataFrame() for _ in x_company]
for i in predictions:
    i[['open', 'low', 'high', 'volume', 'close', 'Positve', 'Negative',
       'Neutral', 'Total', 'NeutralPos', 'NeutralNeg', 'diff', 'exp']] = 0
for i in range(len(x_company)):
    predictions[i][['diff', 'exp']]=model.predict(x_company[i])
# predictions.flatten()
for i in predictions:
    i[['open', 'high', 'low', 'volume', 'close', 'Positve', 'Negative',
       'Neutral', 'Total', 'NeutralPos', 'NeutralNeg']] = 0
predictions[0]

# %%
for i in range(len(predictions)):
    predictions[i][predictions[i].columns]=scaler[i].inverse_transform(predictions[i])
    predictions[i].drop(['open','high', 'low', 'volume', 'close', 'Positve', 'Negative',
                         'Neutral', 'Total', 'NeutralPos', 'NeutralNeg'], axis=1, inplace=True)
predictions[0]
# for i in range(len(predictions)):
#     predictions[i]['high'] = scaler[i]['high'].inverse_transform(
#         np.array(predictions[0]['high']))
#     predictions[i]['diff'] = scaler[i]['diff'].inverse_transform(
#         predictions[i]['diff'])

# %%
y_test = [pd.DataFrame() for _ in x_company]
for i in y_test:
    i[['open', 'low', 'high', 'volume', 'close', 'Positve', 'Negative',
       'Neutral', 'Total', 'NeutralPos', 'NeutralNeg', 'diff', 'exp']] = 0
for i in range(len(y_company)):
    y_test[i][['diff', 'exp']] = y_company[i]
for i in y_test:
    i[['open', 'low', 'high', 'volume', 'close', 'Positve', 'Negative',
       'Neutral', 'Total', 'NeutralPos', 'NeutralNeg']] = 0
y_test[0]

# %%
for i in range(len(y_test)):
    y_test[i][y_test[i].columns] = scaler[i].inverse_transform(
        y_test[i])
    y_test[i].drop(['open', 'high', 'low', 'volume', 'close', 'Positve', 'Negative',
                         'Neutral', 'Total', 'NeutralPos', 'NeutralNeg'], axis=1, inplace=True)
y_test[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 for i in range(len(y_test)):
#       2     y_test[i][y_test[i].columns] = scaler[i].inverse_transform(
#       3         y_test[i])
#       4     y_test[i].drop(['open', 'high', 'low', 'volume', 'close', 'Positve', 'Negative',
#       5                          'Neutral', 'Total', 'NeutralPos', 'NeutralNeg'], axis=1, inplace=True)
#
# NameError: name 'y_test' is not defined

# %%
#choose plotting style

#plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
#plt.style.use('ggplot')
#plt.style.use('seaborn-whitegrid')
#plt.style.use('bmh')
#plt.style.use('seaborn')

# %%
# valid['pred'] = predictions
#Visualize the data
plt.figure(figsize=(16,8))

plt.title('Model prediciton results')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Diff Price USD($)', fontsize=18)
plt.plot(y_test[1]['diff'] , color='red')
plt.plot(predictions[1]['diff'], color='yellow')
plt.legend(['Data', 'Predictions'], loc='lower right')
# plt.savefig('/content/prediction.png')
plt.show()

# %%
# valid['pred'] = predictions
# Visualize the data
plt.figure(figsize=(16, 8))

plt.title('Model prediciton results')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Expected Price USD($)', fontsize=18)
plt.plot(y_test[1]['exp'], color='red')
plt.plot(predictions[1]['exp'], color='yellow')
plt.legend(['Data', 'Predictions'], loc='lower right')
# plt.savefig('/content/prediction.png')
plt.show()

# %% [markdown]
# # Getting predicitions - for tomorrow

# %%
#Get the quote
stock_quote = pd.read_csv("Combining Stock and Twitter Data/RawData/FiveYearData_CSCO.csv")

# %%
new_df=stock_quote.filter(['close'])
#Get last 60 days values and convert into array
last_60_days=new_df[-60:].values

#Scale the data to be values between 0
last_60_days_scaled=scaler.transform(last_60_days)

#Create an empty list
X_test=[]
#Appemd the past 60days
X_test.append(last_60_days_scaled)

#Conver the X_test data into numpy array
X_test = np.array(X_test)

#Reshape the data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
#Get predicted scaled price
pred_price = model.predict(X_test)
#undo the scaling
pred_price=scaler.inverse_transform(pred_price)
print(f'Price of {ticker} tomorrow:{pred_price}')

# %% [markdown]
# ## Getting predicitions for 2 months from now ?

# %%
#Get the quote
stock_quote = web.DataReader(ticker, data_source='yahoo', start='2012-01-01', end='2020-05-24')

new_df=stock_quote.filter(['Open'])
#Get last 60 days values and convert into array
last_60_days=new_df[-60:].values

#Scale the data to be values between 0
last_60_days_scaled=scaler.transform(last_60_days)

#Create an empty list
X_test=[]
#Appemd the past 60days
X_test.append(last_60_days_scaled)

#Conver the X_test data into numpy array
X_test = np.array(X_test)

#Reshape the data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
#Get predicted scaled price
pred_price = model.predict(X_test)
#undo the scaling
pred_price=scaler.inverse_transform(pred_price)
print(f'Opening Price of {ticker} tomorrow:{pred_price}')
